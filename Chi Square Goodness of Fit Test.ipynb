# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
import matplotlib.pyplot as plt

# %%
results = plt.hist(data['radius_mean'])

# %%
results[0]
# Out:
# array([ 19.,  79., 185., 129.,  55.,  50.,  38.,   7.,   4.,   3.])

# %%
[ 6.981,9.0939, 11.2068, 13.3197, 15.4326, 17.5455, 19.6584,
        21.7713, 23.8842, 25.9971, 28.11]
# Out:
# [6.981,
#  9.0939,
#  11.2068,
#  13.3197,
#  15.4326,
#  17.5455,
#  19.6584,
#  21.7713,
#  23.8842,
#  25.9971,
#  28.11]

# %%
(9.0939-6.981)
# Out:
# 2.1129

# %%
6.981 + 1.05645
# Out:
# 8.03745

# %%
9.0939 + 1.05645
# Out:
# 10.15035

# %%
11.2068 + 1.05645
# Out:
# 12.26325

# %%
13.3197 + 1.05645
# Out:
# 14.376149999999999

# %%
15.4326 + 1.05645
# Out:
# 16.48905

# %%
17.5455 + 1.05645
# Out:
# 18.601950000000002

# %%
19.6584 + 1.05645
# Out:
# 20.71485

# %%
21.7713 + 1.05645
# Out:
# 22.82775

# %%
23.8842 + 1.05645
# Out:
# 24.940649999999998

# %%
25.9971 + 1.05645
# Out:
# 27.05355

# %%
plt.hist(data['radius_mean'])

plt.xlabel("radius_mean")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import numpy as np

# %%
Xis = np.array([8.03745,10.15035,12.26325,14.376149999999999,16.48905,18.601950000000002,20.71485,22.82775,24.940649999999998,27.05355])

# %%
import scipy.stats as s

# %%
P_X_equals_Xi_normal = s.norm.pdf(Xis,data['radius_mean'].mean(),data['radius_mean'].std())

# %%
P_X_equals_Xi_normal
# Out:
# array([0.02543368, 0.05988543, 0.09842676, 0.11292375, 0.09043519,
#        0.05055565, 0.01972795, 0.00537371, 0.00102175, 0.00013561])

# %%
Eis_normal = data.shape[0]*P_X_equals_Xi_normal

# %%
Eis_normal
# Out:
# array([14.47176349, 34.07480844, 56.00482623, 64.25361245, 51.45762164,
#        28.76616277, 11.22520348,  3.05764158,  0.58137853,  0.07716342])

# %%
s.chisquare(f_obs=results[0],f_exp=Eis_normal)
# Out:
# Power_divergenceResult(statistic=638.6833121569812, pvalue=1.0368172186725668e-131)

# %%
P_X_equals_Xis_rayleigh = s.rayleigh.pdf(Xis,loc=0,scale=10.295082956524556)

# %%
P_X_equals_Xis_rayleigh
# Out:
# array([0.05591217, 0.0589029 , 0.0569162 , 0.05116284, 0.04314163,
#        0.03430484, 0.02581557, 0.01843203, 0.01250936, 0.0080812 ])

# %%
Eis_rayleigh = data.shape[0]*P_X_equals_Xis_rayleigh

# %%
Eis_rayleigh
# Out:
# array([31.81402691, 33.51574939, 32.38531744, 29.11165758, 24.54758874,
#        19.51945304, 14.68906101, 10.48782718,  7.11782749,  4.59820501])

# %%
s.chisquare(f_obs=results[0],f_exp=Eis_rayleigh)
# Out:
# Power_divergenceResult(statistic=1254.2666929106733, pvalue=2.3280390576391528e-264)

# %%
mode_cap = np.sqrt(np.mean(data['radius_mean']**2)/2)

# %%
mode_cap
# Out:
# 10.295082956524556
